# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('../data/recipes.csv', index_col='RecipeId')

# %%
df = df[df['Description'].str.startswith('Make and share this') == False]
df = df.sample(n=100000)

# %%
df.head()
# Out:
#                                          Name  AuthorId    AuthorName  \
# RecipeId
# 65316       Crunch for Lunch Chicken Stir-Fry     21752      Mirj2338
# 508120                    Brown Rice by a MAN    498595        MHulak
# 304349    Southern Georgia Peachy Baked Beans    488441     pamela t.
# 109199             Kerala Mutton Curry - Mild    186771   MariaBright
# 138395                   Big Batch Beef Sauce    123871  adena mangis
#
#          CookTime PrepTime TotalTime         DatePublished  \
# RecipeId
# 65316       PT20M    PT15M     PT35M  2003-06-20T20:04:00Z
# 508120      PT20M     PT5M     PT25M  2013-10-21T17:46:00Z
# 304349      PT25M    PT15M     PT40M  2008-05-20T17:57:00Z
# 109199       PT1H    PT30M   PT1H30M  2005-01-23T20:00:00Z
# 138395       PT1H    PT15M   PT1H15M  2005-09-21T18:24:00Z
#
#                                                 Description        Images  \
# RecipeId
# 65316     Another winner from the New York Daily News. T...  character(0)
# 508120    Is rice hard to make? It ain't hard mofo. It i...  character(0)
# 304349    This is a nice change of pace from usual brown...  character(0)
# 109199    The recipe is particularly good for those, lik...  character(0)
# 138395    This is a batch of beef that can be frozen and...  character(0)
#
#          RecipeCategory  ... SaturatedFatContent CholesterolContent  \
# RecipeId                 ...
# 65316      Lunch/Snacks  ...                 1.1               54.9
# 508120            Asian  ...                 0.5                0.0
# 304349            Beans  ...                 0.8                3.3
# 109199          Curries  ...                11.9              124.0
# 138395        < 4 Hours  ...                 7.2               82.2
#
#          SodiumContent  CarbohydrateContent  FiberContent  SugarContent  \
# RecipeId
# 65316            191.6                  3.9           1.4           1.7
# 508120            13.6                 71.5           3.2           0.8
# 304349            42.9                 18.8           5.1           3.4
# 109199           130.7                 38.5           6.2          10.1
# 138395           746.7                 15.1           3.9           8.8
#
#           ProteinContent  RecipeServings  RecipeYield  \
# RecipeId
# 65316               23.8             6.0          NaN
# 508120               7.3             4.0      4 bowls
# 304349               6.3            10.0          NaN
# 109199              38.1             4.0          NaN
# 138395              25.9             NaN      15 cups
#
#                                          RecipeInstructions
# RecipeId
# 65316     c("Snip tips off snow peas.", "Wash them and s...
# 508120    c("Simply mang, measure 1 part brown rice to 2...
# 304349    c("Cook bacon, drain and crumble.", "Clean and...
# 109199    c("Mix spices for marinade with the yoghurt an...
# 138395    c("In a Dutch oven over medium heat cook beef,...
#
# [5 rows x 27 columns]

# %%
def str_to_time(str_time):
    
    if pd.isnull(str_time):
        return None
    
    hours = re.findall('[0-9]*H', str_time)
    if hours:
        hours = int(hours[0][:-1])
    else:
        hours='00'
        
    minutes = re.findall('[0-9]*M', str_time)
    if minutes:
        minutes = minutes[0][:-1]
    else:
        minutes = '00'
        
    seconds = re.findall('[0-9]*S', str_time)
    if seconds:
        seconds = seconds[0][:-1]
    else:
        seconds='00'
        
    return f'{hours}:{minutes}:{seconds}'

# %%
timeCols = ['CookTime', 'PrepTime', 'TotalTime']
for col in timeCols:
    df[col] = df[col].apply(str_to_time)

# %%
def parse_instructions(instructions):
    if pd.isnull(instructions):
        return None
    instructions = instructions[3:len(instructions)-2]
    instructions = instructions.split("\", \"")
    instructions = '\n'.join(instructions)
    return instructions

# %%
df['RecipeInstructions'] = df['RecipeInstructions'].apply(parse_instructions)

# %%
def parse_ingredients(row):
    ingredients = row.RecipeIngredientParts
    ingredients = ingredients[3:len(ingredients)-2]
    ingredients = ingredients.split('\", \"')
    ingredients = [ingredient.title() for ingredient in ingredients]
    quantities = row.RecipeIngredientQuantities
    quantities = quantities[3:len(quantities)-2]
    quantities = quantities.split('\", \"')
    
    return dict(zip(ingredients, quantities))

# %%
df['Ingredients'] = [parse_ingredients(row) for row in df.itertuples(index=False)]

# %%
def recipe_yield_fix(quantity:str):
    if pd.isnull(quantity):
        return None
    return quantity.title()

df['RecipeYield'] = df['RecipeYield'].apply(recipe_yield_fix)

# %%
def keywords_fix(keywords: str):
    if pd.isnull(keywords):
        return None
    keywords = keywords[3:len(keywords)-2]
    keywords = keywords.split('\", \"')
    return keywords

df['Keywords'] = df['Keywords'].apply(keywords_fix)

# %%
cols_to_drop = ['AuthorId', 'AuthorName', 'DatePublished', 'Images', 'RecipeIngredientQuantities', 'RecipeIngredientParts', 'ReviewCount']
ndf = df.drop(columns=cols_to_drop)

# %%
ndf.head()
# Out:
#                                          Name  CookTime  PrepTime TotalTime  \
# RecipeId
# 65316       Crunch for Lunch Chicken Stir-Fry  00:20:00  00:15:00  00:35:00
# 508120                    Brown Rice by a MAN  00:20:00   00:5:00  00:25:00
# 304349    Southern Georgia Peachy Baked Beans  00:25:00  00:15:00  00:40:00
# 109199             Kerala Mutton Curry - Mild   1:00:00  00:30:00   1:30:00
# 138395                   Big Batch Beef Sauce   1:00:00  00:15:00   1:15:00
#
#                                                 Description RecipeCategory  \
# RecipeId
# 65316     Another winner from the New York Daily News. T...   Lunch/Snacks
# 508120    Is rice hard to make? It ain't hard mofo. It i...          Asian
# 304349    This is a nice change of pace from usual brown...          Beans
# 109199    The recipe is particularly good for those, lik...        Curries
# 138395    This is a batch of beef that can be frozen and...      < 4 Hours
#
#                                                    Keywords  AggregatedRating  \
# RecipeId
# 65316     [Chicken, Poultry, Meat, Asian, Kosher, < 60 M...               4.0
# 508120    [Low Protein, Low Cholesterol, Healthy, < 30 M...               NaN
# 304349                                             [60 Min]               5.0
# 109199         [Lamb/Sheep, Meat, Asian, Indian, < 4 Hours]               NaN
# 138395                                                 None               5.0
#
#           Calories  FatContent  ...  CholesterolContent  SodiumContent  \
# RecipeId                        ...
# 65316        212.1        10.9  ...                54.9          191.6
# 508120       342.2         2.7  ...                 0.0           13.6
# 304349       123.6         2.5  ...                 3.3           42.9
# 109199       640.9        37.9  ...               124.0          130.7
# 138395       328.2        18.7  ...                82.2          746.7
#
#           CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# RecipeId
# 65316                     3.9           1.4           1.7            23.8
# 508120                   71.5           3.2           0.8             7.3
# 304349                   18.8           5.1           3.4             6.3
# 109199                   38.5           6.2          10.1            38.1
# 138395                   15.1           3.9           8.8            25.9
#
#           RecipeServings  RecipeYield  \
# RecipeId
# 65316                6.0         None
# 508120               4.0      4 Bowls
# 304349              10.0         None
# 109199               4.0         None
# 138395               NaN      15 Cups
#
#                                          RecipeInstructions  \
# RecipeId
# 65316     Snip tips off snow peas.\nWash them and set as...
# 508120    Simply mang, measure 1 part brown rice to 2 pa...
# 304349    Cook bacon, drain and crumble.\nClean and pit ...
# 109199    Mix spices for marinade with the yoghurt and m...
# 138395    In a Dutch oven over medium heat cook beef, on...
#
#                                                 Ingredients
# RecipeId
# 65316     {'Snow Peas': '2', 'Boneless Skinless Chicken ...
# 508120    {'Brown Rice': '2', 'Water': '4', 'Chicken Bou...
# 304349    {'Great Northern Beans': '2', 'Onion': '1', 'B...
# 109199    {'Water': '1/2', 'Bay Leaf': '1/2', 'Yoghurt':...
# 138395    {'Ground Beef': '4', 'Onions': '4', 'Celery Ri...
#
# [5 rows x 21 columns]

# %%
ndf['ProteinPercentage'] = ndf['ProteinContent'] * 4 / ndf['Calories']
ndf['CarbohydratePercentage'] = ndf['CarbohydrateContent'] * 4 / ndf['Calories']
ndf['SugarPercentage'] = ndf['SugarContent'] * 4 / ndf['Calories']
ndf['FatPercentage'] = ndf['FatContent'] * 9 / ndf['Calories']

# %%
ndf.to_csv('../data/recipes_finalv1.csv', index=False)

# %%
##########################################################################################################################
